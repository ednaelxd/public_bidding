# %%
# importação e possíveis ajustes
import pandas as pd 
import numpy as np
# preparação dos modelos
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
# testes de modelos

# %% [markdown]
# ### 1 - Importação e Ajustes iniciais

# %%
df = pd.read_csv(r'C:\Users\ednae\OneDrive\Documentos\Repositórios\TCC\data_processed\new\top_20.csv',index_col = [0])
df.reset_index(drop=True,inplace=True)

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
df.columns
# Out:
# Index(['Código UG_x', 'Código Modalidade Compra_x', 'Código Órgão_x',
#        'Descrição', 'Quantidade Item', 'Código Vencedor',
#        'Código Órgão Superior', 'Município', 'data', 'Total',
#        'valor_individual', 'UF'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    Código UG_x  Código Modalidade Compra_x  Código Órgão_x      Descrição  \
# 0       782801                           6           52131  FIO DE SUTURA
# 1       782801                           6           52131  FIO DE SUTURA
#
#    Quantidade Item  Código Vencedor  Código Órgão Superior       Município  \
# 0                5   14683163000120                  52000    JUIZ DE FORA
# 1                5   14683163000120                  52000  RIO DE JANEIRO
#
#         data  Total  valor_individual  UF
# 0 2022-03-23  300.0             64.11  MG
# 1 2022-05-27  135.0             64.11  RJ

# %% [markdown]
# #### 1.1: Divisão dos dados

# %%
cat_cols = [
    'Descrição','Município','UF'
]

# %% [markdown]
# ### 2 - Pré-Processamento
# - Correção de tipos
# - Correção de faltantes
# - Encoding

# %%
df.drop(cat_cols,axis=1).dtypes
# Out:
# Código UG_x                            int64
# Código Modalidade Compra_x             int64
# Código Órgão_x                         int64
# Quantidade Item                        int64
# Código Vencedor                        int64
# Código Órgão Superior                  int64
# data                          datetime64[ns]
# Total                                float64
# valor_individual                     float64
# dtype: object

# %% [markdown]
# #### 2.1: Arrumando data
# - Código responsável pelo encoding
#     - Encoding Cíclico
# - Incorporação no dataset

# %%
def encode(data, col, max_val):
    data[col + '_sin'] = np.sin(2 * np.pi * data[col]/max_val)
    data[col + '_cos'] = np.cos(2 * np.pi * data[col]/max_val)
    return data

# %%
df['mes'] = df.data.dt.month
df = encode(df,'mes',12)

df['dia'] = df.data.dt.day
df = encode(df, 'dia', 31)

df['ano'] = df.data.dt.year

df.head()
# Out:
#    Código UG_x  Código Modalidade Compra_x  Código Órgão_x      Descrição  \
# 0       782801                           6           52131  FIO DE SUTURA
# 1       782801                           6           52131  FIO DE SUTURA
# 2       782801                           6           52131  FIO DE SUTURA
# 3       782801                           6           52131  FIO DE SUTURA
# 4       782801                           6           52131  FIO DE SUTURA
#
#    Quantidade Item  Código Vencedor  Código Órgão Superior       Município  \
# 0                5   14683163000120                  52000    JUIZ DE FORA
# 1                5   14683163000120                  52000  RIO DE JANEIRO
# 2                5   14683163000120                  52000    JUIZ DE FORA
# 3                5   14683163000120                  52000  RIO DE JANEIRO
# 4                1   14683163000120                  52000    JUIZ DE FORA
#
#         data  Total  valor_individual  UF  mes  mes_sin       mes_cos  dia  \
# 0 2022-03-23  300.0             64.11  MG    3      1.0  6.123234e-17   23
# 1 2022-05-27  135.0             64.11  RJ    5      0.5 -8.660254e-01   27
# 2 2022-03-23  300.0             66.09  MG    3      1.0  6.123234e-17   23
# 3 2022-05-27  135.0             66.09  RJ    5      0.5 -8.660254e-01   27
# 4 2022-03-23  300.0             51.26  MG    3      1.0  6.123234e-17   23
#
#     dia_sin   dia_cos   ano
# 0 -0.998717 -0.050649  2022
# 1 -0.724793  0.688967  2022
# 2 -0.998717 -0.050649  2022
# 3 -0.724793  0.688967  2022
# 4 -0.998717 -0.050649  2022

# %%
df.head(2)
# Out:
#    Código UG_x  Código Modalidade Compra_x  Código Órgão_x      Descrição  \
# 0       782801                           6           52131  FIO DE SUTURA
# 1       782801                           6           52131  FIO DE SUTURA
#
#    Quantidade Item  Código Vencedor  Código Órgão Superior       Município  \
# 0                5   14683163000120                  52000    JUIZ DE FORA
# 1                5   14683163000120                  52000  RIO DE JANEIRO
#
#         data  Total  valor_individual  UF  mes  mes_sin       mes_cos  dia  \
# 0 2022-03-23  300.0             64.11  MG    3      1.0  6.123234e-17   23
# 1 2022-05-27  135.0             64.11  RJ    5      0.5 -8.660254e-01   27
#
#     dia_sin   dia_cos   ano
# 0 -0.998717 -0.050649  2022
# 1 -0.724793  0.688967  2022

# %% [markdown]
# #### 2.2 Conferência de faltantes
# - Numéricos
# - Categóricos

# %%
for i in df.drop(cat_cols,axis=1):
    print(i, df[i].isnull().sum())
# Out:
# Código UG_x 0
# Código Modalidade Compra_x 0
# Código Órgão_x 0
# Quantidade Item 0
# Código Vencedor 0
# Código Órgão Superior 0
# data 0
# Total 0
# valor_individual 0
# mes 0
# mes_sin 0
# mes_cos 0
# dia 0
# dia_sin 0
# dia_cos 0
# ano 0

# %%
for i in df[cat_cols]:
    print(i, df[i].isnull().sum())
# Out:
# Descrição 0
# Município 0
# UF 0

# %% [markdown]
# #### Encoding

# %%
encoder = LabelEncoder()

for i in cat_cols:
    df[i] = encoder.fit_transform(df[i])

# %%
df.head(1)
# Out:
#    Código UG_x  Código Modalidade Compra_x  Código Órgão_x  Descrição  \
# 0       782801                           6           52131          4
#
#    Quantidade Item  Código Vencedor  Código Órgão Superior  Município  \
# 0                5   14683163000120                  52000         57
#
#         data  Total  valor_individual  UF  mes  mes_sin       mes_cos  dia  \
# 0 2022-03-23  300.0             64.11   8    3      1.0  6.123234e-17   23
#
#     dia_sin   dia_cos   ano
# 0 -0.998717 -0.050649  2022

# %%
np.array([1,2,3]).reshape(1,-1)
# Out:
# array([[1, 2, 3]])

# %%
cat_cols.extend(['mes_sin','mes_cos','dia_sin','dia_cos'])

# %%
minmax = MinMaxScaler()
for i in df.drop(cat_cols,axis=1).columns:
    array = np.array(df[i])
    df[i] = minmax.fit_transform(array.reshape(-1,1))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21373 entries, 0 to 21372
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Código UG_x                 21373 non-null  float64
#  1   Código Modalidade Compra_x  21373 non-null  float64
#  2   Código Órgão_x              21373 non-null  float64
#  3   Descrição                   21373 non-null  int32
#  4   Quantidade Item             21373 non-null  float64
#  5   Código Vencedor             21373 non-null  float64
#  6   Código Órgão Superior       21373 non-null  float64
#  7   Município                   21373 non-null  int32
#  8   data                        21373 non-null  float64
#  9   Total                       21373 non-null  float64
#  10  valor_individual            21373 non-null  float64
#  11  UF                          21373 non-null  int32
#  12  mes                         21373 non-null  float64
#  13  mes_sin                     21373 non-null  float64
#  14  mes_cos                     21373 non-null  float64
#  15  dia                         21373 non-null  float64
#  16  dia_sin                     21373 non-null  float64
#  17  dia_cos                     21373 non-null  float64
#  18  ano                         21373 non-null  float64
# dtypes: float64(16), int32(3)
# memory usage: 2.9 MB

# %%
df.describe().T
# Out:
#                               count       mean        std       min  \
# Código UG_x                 21373.0   0.106152   0.175467  0.000000
# Código Modalidade Compra_x  21373.0   0.092432   0.287135  0.000000
# Código Órgão_x              21373.0   0.278884   0.175244  0.000000
# Descrição                   21373.0   5.864642   3.547553  0.000000
# Quantidade Item             21373.0   0.000560   0.011014  0.000000
# Código Vencedor             21373.0   0.219614   0.186394  0.000000
# Código Órgão Superior       21373.0   0.465278   0.285820  0.000000
# Município                   21373.0  68.423431  32.015396  0.000000
# data                        21373.0   0.577074   0.193636  0.000000
# Total                       21373.0   0.006326   0.034023  0.000000
# valor_individual            21373.0   0.001019   0.013944  0.000000
# UF                          21373.0  13.009872   6.550181  0.000000
# mes                         21373.0   0.419408   0.361403  0.000000
# mes_sin                     21373.0   0.400232   0.556642 -1.000000
# mes_cos                     21373.0   0.194070   0.701669 -1.000000
# dia                         21373.0   0.435656   0.291402  0.000000
# dia_sin                     21373.0   0.103174   0.615517 -0.998717
# dia_cos                     21373.0  -0.050219   0.779755 -0.994869
# ano                         21373.0   0.705984   0.455610  0.000000
#
#                                      25%        50%        75%         max
# Código UG_x                 5.389675e-02   0.062446   0.062953    1.000000
# Código Modalidade Compra_x  0.000000e+00   0.000000   0.000000    1.000000
# Código Órgão_x              8.908143e-02   0.226824   0.451113    1.000000
# Descrição                   3.000000e+00   5.000000   8.000000   13.000000
# Quantidade Item             1.357466e-06   0.000009   0.000093    1.000000
# Código Vencedor             7.953096e-02   0.176179   0.336659    1.000000
# Código Órgão Superior       1.395349e-01   0.558140   0.744186    1.000000
# Município                   3.900000e+01  87.000000  94.000000  111.000000
# data                        4.985549e-01   0.580925   0.680636    1.000000
# Total                       6.889732e-05   0.000385   0.002026    1.000000
# valor_individual            1.367821e-06   0.000004   0.000066    1.000000
# UF                          8.000000e+00  16.000000  17.000000   24.000000
# mes                         9.090909e-02   0.272727   0.818182    1.000000
# mes_sin                    -2.449294e-16   0.500000   0.866025    1.000000
# mes_cos                    -5.000000e-01   0.500000   0.866025    1.000000
# dia                         1.333333e-01   0.433333   0.633333    1.000000
# dia_sin                    -3.943559e-01   0.299363   0.651372    0.937752
# dia_cos                    -8.743466e-01  -0.050649   0.688967    1.000000
# ano                         0.000000e+00   1.000000   1.000000    1.000000

# %%
data = df.drop(['data','dia','mes'],axis=1)

# %%
data.to_csv('processed_4models.csv')
